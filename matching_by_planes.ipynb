# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from matching import *
from pipeline import *

# %%
Timer.start()

Config.set_rectify(True)
Config.config_map[Config.key_planes_based_matching_merge_components] = False

pipeline = Pipeline(scene_name="scene1",
                    sequential_files_limit=10,
                    chosen_depth_files=None,
                    save_normals=True,
                    matching_dir="pipeline_with_rectification_foo",
                    matching_difficulties=[0],
                    matching_limit=1,
                    planes_based_matching=True,
                    feature_descriptor=cv.SIFT_create(),
                    normals_dir="work/scene1/normals/simple_diff_mask")

pipeline.run_matching_pipeline()

Timer.end()
# Out:
# Starting the timer
# reading scene info starting
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-f21c6f344397> in <module>
#       4 Config.config_map[Config.key_planes_based_matching_merge_components] = False
#       5
# ----> 6 pipeline = Pipeline(scene_name="scene1",
#       7                     sequential_files_limit=10,
#       8                     chosen_depth_files=None,
#
# ~/ownCloud/diploma_thesis/project/pipeline.py in __init__(self, scene_name, sequential_files_limit, chosen_depth_files, save_normals, normals_dir, feature_descriptor, matching_dir, matching_difficulties, matching_limit, planes_based_matching)
#
# ~/ownCloud/diploma_thesis/project/pipeline.py in __post_init__(self)
#      39
#      40     def __post_init__(self):
# ---> 41         self.scene_info = SceneInfo.read_scene(self.scene_name)
#      42         self.depth_input_dir = megadepth_input_dir(self.scene_name)
#      43
#
# ~/ownCloud/diploma_thesis/project/scene_info.py in read_scene(scene_name)
#      81         Timer.start_check_point("reading scene info")
#      82         img_pairs = read_image_pairs(scene_name)
# ---> 83         img_info_map = read_images(scene_name)
#      84         cameras = read_cameras(scene_name)
#      85         Timer.end_check_point("reading scene info")
#
# ~/ownCloud/diploma_thesis/project/scene_info.py in read_images(scene)
#     127         if line.strip().startswith("#"):
#     128             continue
# --> 129         bits = line.split(" ")
#     130         if odd:
#     131             odd = False
#
# KeyboardInterrupt:

# %%
Timer.start()

Config.set_rectify(True)
Config.config_map[Config.key_planes_based_matching_merge_components] = False

pipeline = Pipeline(scene_name="scene1",
                    sequential_files_limit=10,
                    chosen_depth_files=None,
                    save_normals=True,
                    matching_dir="pipeline_with_rectification_foo",
                    matching_difficulties=[0],
                    matching_limit=1,
                    #
                    planes_based_matching=False,
                    feature_descriptor=cv.SIFT_create(),
                    normals_dir="work/scene1/normals/simple_diff_mask")

pipeline.run_matching_pipeline()

Timer.end()
# Out:
# Starting the timer
# reading scene info starting
# reading scene info finished. It took 4.762078046798706
# Difficulty: 0
# complete image pair matching starting
# WARNING: missing call of end_check_point for label 'complete image pair matching'
# processing img starting
# Processing: frame_0000001535_4
# Creating dir (if not exists already): work/scene1/normals/simple_diff_mask/frame_0000001535_4
# clustering normals starting
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# clustering normals finished. It took 0.6074130535125732
# Will upsample the normals
# processing img finished. It took 2.946483850479126
# processing img starting
# Processing: frame_0000000305_1
# Creating dir (if not exists already): work/scene1/normals/simple_diff_mask/frame_0000000305_1
# clustering normals starting
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# clustering normals finished. It took 0.4423649311065674
# Will upsample the normals
# processing img finished. It took 4.964145183563232
# matching starting
# find_correspondences: save = True, show = True
# Image pair: frame_0000001535_4xframe_0000000305_1:
# Number of correspondences: 162
# Number of not-correspondences: 47
# correctly_matched_point_for_image_pair: unique = 16
# matching finished. It took 4.543663024902344
# errors: (0.03203508733156643, 0.06303480302305742)
# max error: 0.06303480302305742
# complete image pair matching finished. It took 12.464094161987305
# complete image pair matching starting
# Done. Time elapsed from start: 17.2516.,
# Statistics:
# reading scene info called 5 times and it took 4.8317 secs. on average
# clustering normals called 12 times and it took 0.5296 secs. on average
# processing img called 12 times and it took 2.3503 secs. on average
# complete image pair matching called 6 times and it took 11.0810 secs. on average
# matching called 2 times and it took 3.4561 secs. on average

# %%
Timer.start()

#!
Config.set_rectify(False)
Config.config_map[Config.key_planes_based_matching_merge_components] = False

pipeline = Pipeline(scene_name="scene1",
                    sequential_files_limit=10,
                    chosen_depth_files=None,
                    save_normals=True,
                    matching_dir="pipeline_with_rectification_foo",
                    matching_difficulties=[0],
                    matching_limit=1,
                    #!
                    planes_based_matching=False,
                    feature_descriptor=cv.SIFT_create(),
                    normals_dir="work/scene1/normals/simple_diff_mask")

pipeline.run_matching_pipeline()

Timer.end()
# Out:
# Starting the timer
# reading scene info starting
# reading scene info finished. It took 4.854485988616943
# Difficulty: 0
# complete image pair matching starting
# WARNING: missing call of end_check_point for label 'complete image pair matching'
# processing img starting
# Processing: frame_0000001535_4
# Creating dir (if not exists already): work/scene1/normals/simple_diff_mask/frame_0000001535_4
# clustering normals starting
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# clustering normals finished. It took 0.594907283782959
# Will upsample the normals
# processing img finished. It took 1.6122081279754639
# processing img starting
# Processing: frame_0000000305_1
# Creating dir (if not exists already): work/scene1/normals/simple_diff_mask/frame_0000000305_1
# clustering normals starting
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# clustering normals finished. It took 0.45351386070251465
# Will upsample the normals
# processing img finished. It took 1.5181889533996582
# matching starting
# find_correspondences: save = True, show = True
# Image pair: frame_0000001535_4xframe_0000000305_1:
# Number of correspondences: 231
# Number of not-correspondences: 113
# correctly_matched_point_for_image_pair: unique = 40
# matching finished. It took 2.307842969894409
# errors: (0.01192417736618126, 0.018845374278819594)
# max error: 0.018845374278819594
# complete image pair matching finished. It took 5.444076061248779
# complete image pair matching starting
# Done. Time elapsed from start: 10.3221.,
# Statistics:
# reading scene info called 6 times and it took 4.8355 secs. on average
# clustering normals called 14 times and it took 0.5288 secs. on average
# processing img called 14 times and it took 2.2381 secs. on average
# complete image pair matching called 7 times and it took 10.2758 secs. on average
# matching called 3 times and it took 3.0734 secs. on average
